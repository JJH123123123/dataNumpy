# %%
import numpy as np
import pandas as pd

# %%
s1 = pd.Series([1,2,3],index = ['a','b','c'])

# %%
s2 = pd.Series([4,5,6],index = ['d','e','f'])

# %%
s1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s2
# Out:
# d    4
# e    5
# f    6
# dtype: int64

# %%
pd.concat([s1,s2])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
s3 = pd.concat([s1,s2])

# %%
s3
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
pd.concat([s1,s3],axis = 1, join = "inner")
# Out:
#    0  1
# a  1  1
# b  2  2
# c  3  3

# %%
pd.concat([s1,s1,s2], keys = ['one','two', 'three'], axis=1)
# Out:
#    one  two  three
# a  1.0  1.0    NaN
# b  2.0  2.0    NaN
# c  3.0  3.0    NaN
# d  NaN  NaN    4.0
# e  NaN  NaN    5.0
# f  NaN  NaN    6.0

# %%
s1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s2
# Out:
# d    4
# e    5
# f    6
# dtype: int64

# %%
df1 = pd.DataFrame(np.random.rand(6).reshape(3,2),
             index=['a','b','c'], 
             columns =['one', 'two'])

# %%
df2 = pd.DataFrame(np.random.rand(6).reshape(2,3), index = ['a','b'], 
                   columns = ['two', 'three', 'four'])

# %%
df2
# Out:
#         two     three      four
# a  0.648442  0.747216  0.787539
# b  0.290818  0.485658  0.549067

# %%
pd.concat([df1,df2])
# Out:
#         one       two     three      four
# a  0.833812  0.988347       NaN       NaN
# b  0.944773  0.560545       NaN       NaN
# c  0.291095  0.431806       NaN       NaN
# a       NaN  0.648442  0.747216  0.787539
# b       NaN  0.290818  0.485658  0.549067

# %%
pd.concat([df1,df2], join='inner', keys = ['level 0 ', 'level 1'], axis = 1 )
# Out:
#    level 0              level 1
#         one       two       two     three      four
# a  0.833812  0.988347  0.648442  0.747216  0.787539
# b  0.944773  0.560545  0.290818  0.485658  0.549067

# %%
pd.concat([df1, df2], axis=1, join="outer")
# Out:
#         one       two       two     three      four
# a  0.833812  0.988347  0.648442  0.747216  0.787539
# b  0.944773  0.560545  0.290818  0.485658  0.549067
# c  0.291095  0.431806       NaN       NaN       NaN

# %%
pd.concat([df1, df2], axis=1, join='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/86/6ww6nl7s6tldd5_kc41jn2l80000gn/T/ipykernel_76962/3472308811.py in <module>
# ----> 1 pd.concat([df1, df2], axis=1, join='left')
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# ...

# %%
staff_df = pd.DataFrame([{'Name':'Kelly', 'Role':'Director of HR'},

                         {'Name':'Sally', 'Role':'Course Coordinator'}, 
                         {'Name':'James', 'Role':'Grader'}

                         ])

# %%
staff_df
# Out:
#     Name                Role
# 0  Kelly      Director of HR
# 1  Sally  Course Coordinator
# 2  James              Grader

# %%
student_df = pd.DataFrame(
    [
    {'Name':'James','school':'business'},
    {'Name':'Mike','school':'law'},
    {'Name':'Sally','school':'Engineering'},
    {'Name':'David','school':'Engineering'}
    ]
)

# %%
student_df
# Out:
#     name       school
# 0  James     business
# 1   Mike          law
# 2  Sally  Engineering
# 3  David  Engineering

# %%
pd.merge(staff_df, student_df, how = 'outer')
# Out:
#     Name                Role       school
# 0  Kelly      Director of HR          NaN
# 1  Sally  Course Coordinator  Engineering
# 2  James              Grader     business
# 3   Mike                 NaN          law
# 4  David                 NaN  Engineering

# %%
pd.merge(staff_df, student_df, how = 'outer')
# Out:
#     Name                Role       school
# 0  Kelly      Director of HR          NaN
# 1  Sally  Course Coordinator  Engineering
# 2  James              Grader     business
# 3   Mike                 NaN          law
# 4  David                 NaN  Engineering

# %%
pd.merge(staff_df, student_df, how = 'inner')
# Out:
#     Name                Role       school
# 0  Sally  Course Coordinator  Engineering
# 1  James              Grader     business

# %%
staff_df
# Out:
#     Name                Role
# 0  Kelly      Director of HR
# 1  Sally  Course Coordinator
# 2  James              Grader

# %%
pd.merge(staff_df, student_df, how = 'left') # 기준 staff__df
# Out:
#     Name                Role       school
# 0  Kelly      Director of HR          NaN
# 1  Sally  Course Coordinator  Engineering
# 2  James              Grader     business

# %%
pd.merge(staff_df, student_df, how = 'right') # 기준 오른쪽
# Out:
#     Name                Role       school
# 0  James              Grader     business
# 1   Mike                 NaN          law
# 2  Sally  Course Coordinator  Engineering
# 3  David                 NaN  Engineering

# %%
pd.merge(staff_df, student_df)
# Out:
#     Name                Role       school
# 0  Sally  Course Coordinator  Engineering
# 1  James              Grader     business

# %%
# merge default how = 'inner'

# %%
pd.concat([staff_df, student_df], axis=0)
# Out:
#     Name                Role       school
# 0  Kelly      Director of HR          NaN
# 1  Sally  Course Coordinator          NaN
# 2  James              Grader          NaN
# 0  James                 NaN     business
# 1   Mike                 NaN          law
# 2  Sally                 NaN  Engineering
# 3  David                 NaN  Engineering

# %%
school_df = pd.DataFrame([{'school':"business", 'Dean':'Kevin'},
                          {'school':"law", 'Dean':'Luke'},
                          {'school':"Engineering", 'Dean':'Kevin'},
                         ])

# %%
school_df
# Out:
#         school   Dean
# 0     business  Kevin
# 1          law   Luke
# 2  Engineering  Kevin

# %%
student_df
# Out:
#     Name       school
# 0  James     business
# 1   Mike          law
# 2  Sally  Engineering
# 3  David  Engineering

# %%
pd.merge(student_df, school_df)
# Out:
#     Name       school   Dean
# 0  James     business  Kevin
# 1   Mike          law   Luke
# 2  Sally  Engineering  Kevin
# 3  David  Engineering  Kevin

# %%
department_df = pd.DataFrame([{'school':'business', 'Department':'Finance'},
                              {'school':'business', 'Department':'accounting'},
                              {'school':'law', 'Department':'law'},
                              {'school':'Engineering', 'Department':'civil engineering'},
                              {'school':'Engineering', 'Department':'mechanical engineering'}
                                 ])

# %%
pd.merge(student_df, department_df) # multiple row
# Out:
#     Name       school              Department
# 0  James     business                 Finance
# 1  James     business              accounting
# 2   Mike          law                     law
# 3  Sally  Engineering       civil engineering
# 4  Sally  Engineering  mechanical engineering
# 5  David  Engineering       civil engineering
# 6  David  Engineering  mechanical engineering

# %%
salary_df = pd.DataFrame([{'Employee':'Kelly', 'Salary':1000},
                          {'Employee':'Sally', 'Salary':200},
                          {'Employee':'James', 'Salary':100},                          

                         ])

# %%
salary_df
# Out:
#   Employ  Salary
# 0  Kelly    1000
# 1  Sally     200
# 2  James     100

# %%
staff_df
# Out:
#     Name                Role
# 0  Kelly      Director of HR
# 1  Sally  Course Coordinator
# 2  James              Grader

# %%
pd.merge(staff_df, salary_df, left_on = 'Name', right_on = 'Employee' )
# Out:
#     Name                Role Employee  Salary
# 0  Kelly      Director of HR    Kelly    1000
# 1  Sally  Course Coordinator    Sally     200
# 2  James              Grader    James     100

# %%
pd.merge(staff_df, salary_df, left_on = "Name", right_on = "Employee").drop('Employee', axis = 1) 
# column 기준 remove
# Out:
#     Name                Role  Salary
# 0  Kelly      Director of HR    1000
# 1  Sally  Course Coordinator     200
# 2  James              Grader     100

# %%
df3 = pd.DataFrame({'a':[1,2,3], 'b':['one','two','three'], 'c':[10,20,30]})

# %%
df4 = pd.DataFrame({'a':[1,2,3,4,5,6],'b':['one','due', 'three', 'quattro', 'cinque', 'sei'], 'd':[10+10*i for i in range(1,7)]})

# %%
df4
# Out:
#    a        b   d
# 0  1      one  20
# 1  2      due  30
# 2  3    three  40
# 3  4  quattro  50
# 4  5   cinque  60
# 5  6      sei  70

# %%
df3
# Out:
#    a      b   c
# 0  1    one  10
# 1  2    two  20
# 2  3  three  30

# %%
pd.merge(df3, df4, on = 'a')
# Out:
#    a    b_x   c    b_y   d
# 0  1    one  10    one  20
# 1  2    two  20    due  30
# 2  3  three  30  three  40

# %%
pd.merge(df3,df4, how = 'outer')
# Out:
#    a        b     c     d
# 0  1      one  10.0  20.0
# 1  2      two  20.0   NaN
# 2  3    three  30.0  40.0
# 3  2      due   NaN  30.0
# 4  4  quattro   NaN  50.0
# 5  5   cinque   NaN  60.0
# 6  6      sei   NaN  70.0

# %%
pd.merge(df3,df4, how='outer', on ='a')
# Out:
#    a    b_x     c      b_y   d
# 0  1    one  10.0      one  20
# 1  2    two  20.0      due  30
# 2  3  three  30.0    three  40
# 3  4    NaN   NaN  quattro  50
# 4  5    NaN   NaN   cinque  60
# 5  6    NaN   NaN      sei  70

# %%
pd.merge(df3,df4, how='left', on ='b')
# Out:
#    a_x      b   c  a_y     d
# 0    1    one  10  1.0  20.0
# 1    2    two  20  NaN   NaN
# 2    3  three  30  3.0  40.0

# %%
pd.merge(df3,df4, how ='right', sort=True)
# Out:
#    a        b     c   d
# 0  1      one  10.0  20
# 1  2      due   NaN  30
# 2  3    three  30.0  40
# 3  4  quattro   NaN  50
# 4  5   cinque   NaN  60
# 5  6      sei   NaN  70

# %%
pd.merge(df3,df4, on = 'b')
# Out:
#    a_x      b   c  a_y   d
# 0    1    one  10    1  20
# 1    3  three  30    3  40

# %%
pd.merge(df3,df4, how = 'outer', on = 'a', suffixes=['_L', '_R'])
# Out:
#    a    b_L     c      b_R   d
# 0  1    one  10.0      one  20
# 1  2    two  20.0      due  30
# 2  3  three  30.0    three  40
# 3  4    NaN   NaN  quattro  50
# 4  5    NaN   NaN   cinque  60
# 5  6    NaN   NaN      sei  70

# %%
pd.merge(df3,df4, how = 'outer', suffixes = ['_L', '_R']).sort_index(axis=1)
# Out:
#    a        b     c     d
# 0  1      one  10.0  20.0
# 1  2      two  20.0   NaN
# 2  3    three  30.0  40.0
# 3  2      due   NaN  30.0
# 4  4  quattro   NaN  50.0
# 5  5   cinque   NaN  60.0
# 6  6      sei   NaN  70.0

# %%
pd.merge(df3, df4, how = 'outer', on = 'b', suffixes = ['_L', '_R'], sort = True)
# ??
# Out:
#    a_L        b     c  a_R     d
# 0  NaN   cinque   NaN  5.0  60.0
# 1  NaN      due   NaN  2.0  30.0
# 2  1.0      one  10.0  1.0  20.0
# 3  NaN  quattro   NaN  4.0  50.0
# 4  NaN      sei   NaN  6.0  70.0
# 5  3.0    three  30.0  3.0  40.0
# 6  2.0      two  20.0  NaN   NaN

# %%
df3
# Out:
#    a      b   c
# 0  1    one  10
# 1  2    two  20
# 2  3  three  30

# %%
pd.merge(df3,df4, on = 'd')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/86/6ww6nl7s6tldd5_kc41jn2l80000gn/T/ipykernel_76962/3017538901.py in <module>
# ----> 1 pd.merge(df3,df4, on = 'd')
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# ...

# %%
# df4.sort_values()
df4.sort_values(by='d', ascending = False)
# Out:
#    a        b   d
# 5  6      sei  70
# 4  5   cinque  60
# 3  4  quattro  50
# 2  3    three  40
# 1  2      due  30
# 0  1      one  20

# %%
# grouping

# %%
import requests
import pprint
import json

# %%
response = requests.get(url)

# %%
contents = response.text

# %%
contents
# Out:
# '{"response":{"header":{"resultCode": "30","resultMsg":"SERVICE KEY IS NOT REGISTERED ERROR."}}}'

# %%
tips = pd.read_csv("../suwon1.csv", encoding="CP949")

# %%
tips.head()
# Out:
#           기준일 시군구명            구분   품목        규격 및 단위     물가동향     데이터기준일자
# 0  2023-03-04  장안구  개인서비스요금(외식비)  설렁탕        1인분(보통)   8938.0  2023-03-28
# 1  2023-03-04  장안구  개인서비스요금(외식비)   냉면    물냉면,1인분(보통)   7900.0  2023-03-28
# 2  2023-03-04  장안구  개인서비스요금(외식비)  비빕밥        1인분(보통)   7150.0  2023-03-28
# 3  2023-03-04  장안구  개인서비스요금(외식비)  갈비탕        1인분(보통)  12450.0  2023-03-28
# 4  2023-03-04  장안구  개인서비스요금(외식비)  삼계탕  닭 1마리,1인분(보통)  14778.0  2023-03-28

# %%
chungnam = pd.read_csv("../chungnam1.csv", encoding="CP949")
chungnam
# Out:
#          연도  월     물품  지역명     물가
# 0      2012  5    밀가루  청양군      0
# 1      2012  5    콩기름  청양군      0
# 2      2012  7    밀가루  청양군      0
# 3      2012  8    밀가루  청양군      0
# 4      2012  8  혼합조미료  태안군      0
# ...     ... ..    ...  ...    ...
# 17672  2022  7    참기름  공주시  12000
# 17673  2022  8    참기름  공주시  12000
# 17674  2022  8    참기름  천안시  12000
# 17675  2022  9    참기름  공주시  12000
# 17676  2022  9    참기름  천안시  12000
#
# [17677 rows x 5 columns]

# %%
chungnam.loc[:,'물품'].unique()
# Out:
# array(['밀가루', '콩기름', '혼합조미료', '시판생수', '봉지라면', '소주', '맥주', '설탕', '간장',
#        '참기름', '고추장'], dtype=object)

# %%
chungnam.where(chungnam['물품'] == '콩기름', 0)
# Out:
#          연도  월   물품  지역명  물가
# 0         0  0    0    0   0
# 1      2012  5  콩기름  청양군   0
# 2         0  0    0    0   0
# 3         0  0    0    0   0
# 4         0  0    0    0   0
# ...     ... ..  ...  ...  ..
# 17672     0  0    0    0   0
# 17673     0  0    0    0   0
# 17674     0  0    0    0   0
# 17675     0  0    0    0   0
# 17676     0  0    0    0   0
#
# [17677 rows x 5 columns]

# %%
chungnam.groupby('물가')
# chungnam[:,['연도','월']] = chungnam[:,['연도','월']]

# %%
prices = pd.DataFrame(chungnam.groupby('물품'))

# %%
sesami = prices.iloc[0,1] # 간장

# %%
sesami.sort_values(by= '물가')
# Out:
#          연도   월  물품  지역명     물가
# 16742  2022   2  간장  부여군    300
# 17205  2022   3  간장  부여군   3000
# 16112  2021  12  간장  부여군   3000
# 16111  2021  11  간장  부여군   3000
# 16110  2021  10  간장  부여군   3000
# ...     ...  ..  ..  ...    ...
# 17660  2022   3  간장  홍성군  11000
# 17662  2022   4  간장  홍성군  11000
# 17666  2022   7  간장  홍성군  11000
# 17667  2022   9  간장  홍성군  11000
# 17670  2022   6  간장  홍성군  12000
#
# [1607 rows x 5 columns]

# %%
chungnam[chungnam['물품'] == '콩기름'].sum(numeric_only = True)
# Out:
# 연도    3240679
# 월       10542
# 물가    9290000
# dtype: int64

# %%
len(chungnam[chungnam['물품'] == '콩기름'])
# Out:
# 1607

# %%
9290000/ 1607
# Out:
# 5780.9583074051025

# %%
chungnam.groupby('물품')['물가'].sum()
# Out:
# 물품
# 간장        8761300
# 고추장      12736000
# 맥주        1921000
# 밀가루       5854000
# 봉지라면      1282900
# 설탕        3233000
# 소주        1667200
# 시판생수       670900
# 참기름      10157000
# 콩기름       9290000
# 혼합조미료     4437200
# Name: 물가, dtype: int64

# %%
tips.groupby('품목')['물가동향'].sum()
# how to show all
# Out:
# 품목
# PC방 이용료       13478.0
# 갈비탕          149040.0
# 갈치           103347.0
# 고등어           48411.0
# 골프연습장이용료    2939781.0
#               ...
# 탕수육          259360.0
# 택배수수료         89299.0
# 피자           190698.0
# 햄버거           49452.0
# 호박            28921.0
# Name: 물가동향, Length: 62, dtype: float64

# %%
tips.groupby('품목')['물가동향'].agg('mean')
# Out:
# 품목
# PC방 이용료       1123.166667
# 갈비탕          12420.000000
# 갈치            8612.250000
# 고등어           4034.250000
# 골프연습장이용료    244981.750000
#                 ...
# 탕수육          21613.333333
# 택배수수료         7441.583333
# 피자           15891.500000
# 햄버거           4121.000000
# 호박            2410.083333
# Name: 물가동향, Length: 62, dtype: float64

# %%
chungnam.groupby('물품')['물가'].agg('mean')
# Out:
# 물품
# 간장       5451.960174
# 고추장      7925.326696
# 맥주       1195.395146
# 밀가루      3642.812694
# 봉지라면      798.319851
# 설탕       2011.823273
# 소주       1037.461108
# 시판생수      417.485999
# 참기름      6320.472931
# 콩기름      5780.958307
# 혼합조미료    2761.169882
# Name: 물가, dtype: float64

# %%
chungnam.groupby(['연도','월','물품'])['물가'].mean()
# Out:
# 연도    월   물품
# 2012  5   간장       4214.285714
#           고추장      6571.428571
#           맥주       1000.000000
#           밀가루      3428.571429
#           봉지라면      635.714286
#                       ...
# 2022  10  소주       1200.000000
#           시판생수      380.000000
#           참기름      8000.000000
#           콩기름      7600.000000
#           혼합조미료    3400.000000
# Name: 물가, Length: 1386, dtype: float64

# %%
chungnam.groupby(['연도','월','물품'])['물가'].agg(['min','max'])
# Out:
#                 min   max
# 연도   월  물품
# 2012 5  간장     3000  6000
#         고추장    4000  8000
#         맥주     1000  1000
#         밀가루       0  5000
#         봉지라면    600   700
# ...             ...   ...
# 2022 10 소주     1000  2000
#         시판생수    200   500
#         참기름    6000  9000
#         콩기름    5000  9000
#         혼합조미료  2000  4000
#
# [1386 rows x 2 columns]

# %%
chungnam.groupby(['연도','월','물품'])['물가'].agg(['min','max']).unstack()
# Out:
#           min                                                      ...    max  \
# 물품         간장   고추장    맥주   밀가루 봉지라면    설탕    소주 시판생수   참기름   콩기름  ...    고추장
# 연도   월                                                             ...
# 2012 5   3000  4000  1000     0  600  2000  1000  300  4000     0  ...   8000
#      6   4000  5000  1000  1000  600  1000  1000  300  4000  4000  ...   8000
#      7   4000  6000  1000     0  600  2000  1000  300  4000  4000  ...   8000
#      8   4000  6000  1000     0  600  2000  1000  300  4000  2000  ...   8000
#      9   4000  6000  1000  3000  600  2000  1000  300  4000     0  ...   8000
# ...       ...   ...   ...   ...  ...   ...   ...  ...   ...   ...  ...    ...
# 2022 6   4000  6000  1000  3000  700  2000  1000  300  6000  3000  ...  10000
#      7   4000  6000  1000  2000  700  2000  1000  200  5000     0  ...  10000
#      8   4000  6000  1000  2000  600  2000  1000  200  4000  5000  ...  10000
# ...

# %%
chungnam.groupby(['연도','월','물품'])['물가'].mean().unstack()
# Out:
# 물품                간장          고추장           맥주          밀가루         봉지라면  \
# 연도   월
# 2012 5   4214.285714  6571.428571  1000.000000  3428.571429   635.714286
#      6   4466.666667  6666.666667  1066.666667  3533.333333   653.333333
#      7   4500.000000  6937.500000  1000.000000  3437.500000   650.000000
#      8   4666.666667  7133.333333  1000.000000  3200.000000   666.666667
#      9   4666.666667  7200.000000  1333.333333  4066.666667   680.000000
# ...              ...          ...          ...          ...          ...
# 2022 6   6666.666667  8111.111111  1888.888889  5000.000000  1144.444444
#      7   7000.000000  8200.000000  2400.000000  4900.000000  1110.000000
#      8   6875.000000  7875.000000  1750.000000  5000.000000   750.000000
#      9   7125.000000  8250.000000  1875.000000  5125.000000   800.000000
#      10  6200.000000  8800.000000  1800.000000  4800.000000   820.000000
#
# 물품                설탕           소주        시판생수          참기름          콩기름  \
# 연도   월
# ...

# %%
chungnam.groupby(['연도','월','물품'])['물가'].describe()
# Out:
#                count         mean          std     min     25%     50%  \
# 연도   월  물품
# 2012 5  간장      14.0  4214.285714   801.783726  3000.0  4000.0  4000.0
#         고추장     14.0  6571.428571   937.614462  4000.0  6000.0  7000.0
#         맥주      14.0  1000.000000     0.000000  1000.0  1000.0  1000.0
#         밀가루     14.0  3428.571429  1157.868447     0.0  3000.0  4000.0
#         봉지라면    14.0   635.714286    49.724516   600.0   600.0   600.0
# ...              ...          ...          ...     ...     ...     ...
# 2022 10 소주       5.0  1200.000000   447.213595  1000.0  1000.0  1000.0
#         시판생수     5.0   380.000000   130.384048   200.0   300.0   400.0
#         참기름      5.0  8000.000000  1414.213562  6000.0  7000.0  9000.0
#         콩기름      5.0  7600.000000  1516.575089  5000.0  8000.0  8000.0
#         혼합조미료    5.0  3400.000000   894.427191  2000.0  3000.0  4000.0
#
#                   75%     max
# 연도   월  물품
# 2012 5  간장     4750.0  6000.0
# ...

# %%
chungnam.groupby(['연도','월','물품']).apply(lambda x : x['물가'].max() - x['물가'].min())
# Out:
# 연도    월   물품
# 2012  5   간장       3000
#           고추장      4000
#           맥주          0
#           밀가루      5000
#           봉지라면      100
#                    ...
# 2022  10  소주       1000
#           시판생수      300
#           참기름      3000
#           콩기름      4000
#           혼합조미료    2000
# Length: 1386, dtype: int64

# %%
df_filltered = chungnam.groupby(['연도','월','물품']).filter(lambda x: x['물가'].min() > 6000  ).sort_values(by = "물가")

# %%
df_filltered
# Out:
#          연도   월   물품  지역명     물가
# 3089   2013  10  고추장  보령시   7000
# 3151   2013  10  고추장  홍성군   7000
# 3211   2013  10  고추장  공주시   8000
# 3212   2013  10  고추장  천안시   8000
# 3224   2013  10  고추장  부여군   8000
# ...     ...  ..  ...  ...    ...
# 17527  2022   9  콩기름  계룡시   8000
# 17543  2022   9  콩기름  홍성군   8000
# 17594  2022   9  콩기름  예산군   9000
# 17629  2022   9  콩기름  공주시  10000
# 17630  2022   9  콩기름  천안시  10000
#
# [94 rows x 5 columns]
