# %%
import numpy as np
import pandas as pd
import platform
import matplotlib

# %%
from matplotlib import pyplot as plt

# %%
crime_when = pd.read_csv("crime_when.csv", encoding = "CP949")
crime_when
# Out:
#      범죄대분류        범죄중분류  0시00분-02시59분  03시00분-05시59분  06시00분-08시59분  \
# 0     강력범죄         살인기수            15             21             20
# 1     강력범죄        살인미수등            33             50             29
# 2     강력범죄           강도           105            131             44
# 3     강력범죄           강간           630            885            417
# 4     강력범죄         유사강간           102            110             57
# 5     강력범죄         강제추행          1855           1921           1293
# 6     강력범죄  기타 강간 강제추행등            36             47             12
# 7     강력범죄           방화           144            151            105
# 8     절도범죄           절도         13088          14167          13094
# 9     폭력범죄           상해          4166           3408           2247
# 10    폭력범죄           폭행         19226          16377           9345
# 11    폭력범죄        체포 감금            96            106             76
# 12    폭력범죄           협박          1316           1036           1339
# ...

# %%
# goal : % 로 표현 
crime_when.describe()
# Out:
#        0시00분-02시59분  03시00분-05시59분  06시00분-08시59분  09시00분-11시59분  \
# count     38.000000      38.000000      38.000000      38.000000
# mean    2476.184211    2275.552632    2328.631579    4821.973684
# std     5472.712885    5120.263949    6532.695596   10822.444125
# min        0.000000       0.000000       0.000000      10.000000
# 25%       11.250000      14.250000      21.250000     121.250000
# 50%      139.500000     126.500000      92.500000     453.000000
# 75%     1595.000000    1385.250000    1323.000000    2138.000000
# max    24513.000000   23438.000000   37189.000000   44265.000000
#
#        12시00분-14시59분  15시00분-17시59분  18시00분-20시59분  21시00분-23시59분  \
# count      38.000000      38.000000      38.000000      38.000000
# mean     4449.736842    4529.131579    4618.500000    5381.789474
# std     10122.755278   10557.470940   10974.673164   13132.320698
# min         9.000000       6.000000       3.000000       2.000000
# ...

# %%
crime_when.groupby(['범죄대분류','월'])['범죄중분류'].describe()
# Out:
#              count unique          top freq
# 범죄대분류  월
# 강력범죄   45        1      1         살인기수    1
#        53        1      1  기타 강간 강제추행등    1
#        70        1      1        살인미수등    1
#        99        1      1         유사강간    1
#        113       1      1           강도    1
#        181       1      1           방화    1
#        686       1      1           강간    1
#        2272      1      1         강제추행    1
# 교통범죄   51459     1      1         교통범죄    1
# 기타범죄   39244     1      1         기타범죄    1
# 노동범죄   162       1      1         노동범죄    1
# 마약범죄   1278      1      1         마약범죄    1
# 병역범죄   3068      1      1         병역범죄    1
# 보건범죄   2051      1      1         보건범죄    1
# 선거범죄   90        1      1         선거범죄    1
# 안보범죄   25        1      1         안보범죄    1
# 절도범죄   26239     1      1           절도    1
# 지능범죄   22        1      1       유가증권인지    1
#        46        1      1          증수뢰    1
#        108       1      1         직무유기    1
# ...

# %%
month = crime_when.loc[:,'월']
month.index = list(crime_when['범죄중분류'])
month.sort_values(ascending = False)
# Out:
# 사기             52740
# 교통범죄           51459
# 기타범죄           39244
# 절도             26239
# 폭행             19966
# 특별경제범죄          8724
# 횡령              8559
# 손괴              7974
# 상해              4908
# 병역범죄            3068
# 협박              3013
# 강제추행            2272
# 문서 인장           2130
# 보건범죄            2051
# 성풍속범죄           1957
# 마약범죄            1278
# 폭력행위등           1126
# 도박범죄            1106
# 배임               859
# 공갈               818
# 환경범죄             749
# 강간               686
# 체포 감금            189
# 통화               186
# 방화               181
# 노동범죄             162
# 직권남용             126
# 강도               113
# 직무유기             108
# 유사강간              99
# 선거범죄              90
# 살인미수등             70
# 기타 강간 강제추행등       53
# 증수뢰               46
# 살인기수              45
# 약취 유인             40
# 안보범죄              25
# 유가증권인지            22
# Name: 월, dtype: int64

# %%
day = crime_when.loc[:,'일']
day.index = list(crime_when['범죄중분류'])
day.sort_values(ascending = False)
# Out:
# 교통범죄           47698
# 폭행             25865
# 절도             25466
# 기타범죄           25278
# 사기             20814
# 손괴              8617
# 횡령              7231
# 상해              5693
# 특별경제범죄          3948
# 협박              2886
# 강제추행            2580
# 성풍속범죄           1614
# 폭력행위등           1544
# 보건범죄             934
# 도박범죄             915
# 강간               869
# 마약범죄             789
# 문서 인장            620
# 공갈               483
# 배임               248
# 방화               209
# 체포 감금            180
# 환경범죄             168
# 유사강간             145
# 강도               111
# 병역범죄             111
# 노동범죄              85
# 살인미수등             71
# 선거범죄              65
# 기타 강간 강제추행등       58
# 직권남용              44
# 살인기수              38
# 안보범죄              36
# 통화                35
# 약취 유인             27
# 직무유기              24
# 증수뢰               13
# 유가증권인지             8
# Name: 일, dtype: int64

# %%
#### crime_columns = crime_when.columns
crime_when.loc[:,crime_columns[1:10]].apply(pd.DataFrame.cummax)
# Out:
#     범죄중분류  0시00분-02시59분  03시00분-05시59분  06시00분-08시59분  09시00분-11시59분  \
# 0    살인기수            15             21             20             28
# 1   살인미수등            33             50             29             44
# 2   살인미수등           105            131             44             59
# 3   살인미수등           630            885            417            293
# 4    유사강간           630            885            417            293
# 5    유사강간          1855           1921           1293           1163
# 6    유사강간          1855           1921           1293           1163
# 7    유사강간          1855           1921           1293           1163
# 8      절도         13088          14167          13094          21501
# 9      절도         13088          14167          13094          21501
# 10     폭행         19226          16377          13094          21501
# 11     폭행         19226          16377          13094          21501
# 12     협박         19226          16377          13094          21501
# ...

# %%
crime_when.drop('미상',axis= 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/86/6ww6nl7s6tldd5_kc41jn2l80000gn/T/ipykernel_8637/1261075908.py in <module>
# ----> 1 crime_when.drop('미상',axis= 1, inplace=True)
#       2 import platform
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
crime_new = crime_when.T

# %%
matplotlib.rc('font', family='AppleGothic')
crime_new
# Out:
#                  0      1     2     3     4     5            6     7      8   \
# 범죄대분류          강력범죄   강력범죄  강력범죄  강력범죄  강력범죄  강력범죄         강력범죄  강력범죄   절도범죄
# 범죄중분류          살인기수  살인미수등    강도    강간  유사강간  강제추행  기타 강간 강제추행등    방화     절도
# 0시00분-02시59분     15     33   105   630   102  1855           36   144  13088
# 03시00분-05시59분    21     50   131   885   110  1921           47   151  14167
# 06시00분-08시59분    20     29    44   417    57  1293           12   105  13094
# 09시00분-11시59분    28     44    59   293    62  1163           26   124  21501
# 12시00분-14시59분    38     46    68   325    60  1300           20   109  27167
# 15시00분-17시59분    33     60    72   311    55  1706           37   173  28553
# 18시00분-20시59분    43     66    81   425    66  2189           30   189  27229
# 21시00분-23시59분    49     82   107   719    89  2901           40   228  20568
# 일                38     71   111   869   145  2580           58   209  25466
# ...

# %%
crime_new.columns = crime_new.iloc[0,:]
crime_new.drop(['범죄대분류','범죄중분류','일','월','화','수','목','금','토'],axis=0,inplace= True)

# %%
fig, ax = plt.subplots(figsize=(14,13))
crime_new.groupby("범죄대분류",axis=1).sum().plot(kind='line', ax=ax)
# Out:
# <AxesSubplot:>
