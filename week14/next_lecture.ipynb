# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
f = lambda x : 1/(1+np.exp(-x))
# Out:
# array([0.73105858, 0.88079708, 0.95257413])

# %%
h = 0.002
domain = np.arange(-13,13,h)
plt.plot(domain, f(domain))
plt.title("f = lambda x : 1/(1+np.exp(-x)) x")
# Out:
# Text(0.5, 1.0, 'f = lambda x : 1/(1+np.exp(-x)) x')
